# %% [markdown]
# ## Markdown document to pull data for analysis
# ---
# **We will be using ERA5 monthly data retireved from the CDS (coppernicus data store) [HERE](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-monthly-means?tab=overview)**

# %%
## Define Paths:

STORAGE_PATH = "/gws/nopw/j04/global_ex/chingosa/ERA5_monthly/t2m.nc"    # Path to store downloaded data - change as needed

# %%
import cdsapi

## Define Paths:

STORAGE_PATH = "/gws/nopw/j04/global_ex/chingosa/ERA5_monthly/t2m.nc"    # Path to store downloaded data - change as needed

dataset = "reanalysis-era5-single-levels-monthly-means"
request = {
    "product_type": ["monthly_averaged_reanalysis"],
    "variable": [
        "2m_dewpoint_temperature",
    ],
    "year": ["1970", "1971", "1972",
        "1973", "1974", "1975",
        "1976", "1977", "1978",
        "1979",
        "1980", "1981", "1982",
        "1983", "1984", "1985",
        "1986", "1987", "1988",
        "1989", "1990", "1991",
        "1992", "1993", "1994",
        "1995", "1996", "1997",
        "1998", "1999", "2000",
        "2001", "2002", "2003",
        "2004", "2005", "2006",
        "2007", "2008", "2009",
        "2010", "2011", "2012",
        "2013", "2014", "2015",
        "2016", "2017", "2018",
        "2019", "2020", "2021",
        "2022", "2023", "2024",
        "2025"
    ],
    "month": [
        "01", "02", "03",
        "04", "05", "06",
        "07", "08", "09",
        "10", "11", "12"
    ],
    "time": ["00:00"],
    "data_format": "netcdf",
    "download_format": "unarchived"}

client = cdsapi.Client()
client.retrieve(dataset, request).download(STORAGE_PATH)
# Out:
# 2026-01-31 09:46:44,958 INFO Request ID is 70bba3f0-8824-43be-9a05-f5db30c48279
# 2026-01-31 09:46:45,023 INFO status has been updated to accepted
# 2026-01-31 09:46:58,492 INFO status has been updated to running
# 2026-01-31 09:47:06,133 INFO status has been updated to successful
# e77fd1b8d283d8904d4a03628edda5ce.nc:   0%|          | 0.00/856M [00:00<?, ?B/s]
# '/gws/nopw/j04/global_ex/chingosa/ERA5_monthly/t2m.nc'

# %%
import xarray as xr
xr.open_dataset('/gws/nopw/j04/global_ex/chingosa/ERA5_monthly/t2m.nc')
# Out:
# <xarray.Dataset> Size: 3GB
# Dimensions:     (valid_time: 672, latitude: 721, longitude: 1440)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 5kB 1970-01-01 ... 2025-12-01
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     expver      (valid_time) <U4 11kB ...
# Data variables:
#     d2m         (valid_time, latitude, longitude) float32 3GB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-01-31T09:40 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# !du -sh /gws/nopw/j04/global_ex/chingosa/ERA5_monthly/*
# Out:
# 864M	/gws/nopw/j04/global_ex/chingosa/ERA5_monthly/t2m.nc
